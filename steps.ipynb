# %% [markdown]
# make virtual environment
# activate virtual environmen
# install requirements file
# _Ensure Jupyter can see your environment
# Install ipykernel in your virtual environment if not already installed:
# pip install ipykernel
